# %%
import scanpy as sc
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from pySTIM import to_hex, crop, get_color_map
# Out:
# /home/spatial/anaconda3/envs/scvi-env/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
adata = sc.read_h5ad("../Xenium_all.h5ad")

# %%
sham_ad = adata[adata.obs.ident == "ShamR"].copy()

# %%
cmap_red = mcolors.LinearSegmentedColormap.from_list('WhRd',['#f2f2f2','#ffdbdb', '#fc0303'], N=256)

# %%
pst.plot_scatter_image(sham_ad,
                  crop=True,
                  xlims = [2625,2825], 
                  ylims=[3675,3825],
                  genes = ["Nphs2"], 
                  dpi = 200,
                  color_by="celltype",
                  pt_size=300, 
                  image=False, 
                  ticks=False, 
                  img_alpha = 1,
                  pt_alpha=0.8,
                  cmap = cmap_red,
                  image_key="ShamR",
                  legend_col=1,
                  save = "Pod_exp.png",
                  format = "png")

# %%
pst.plot_scatter_image(sham_ad[sham_ad.obs.celltype_plot.isin(["Pod"])], 
                  crop=True,
                  xlims = [2625,2825], 
                  ylims=[3675,3825],
                  dpi = 200,
                  color_by="celltype",
                  pt_size=500, 
                  image=True, 
                  ticks=False, 
                  img_alpha = 1,
                  pt_alpha=0.8,
                  cmap = cmap,
                  image_key="ShamR",
                  legend_col=1,
                  save = "Pod.svg")

# %%
shamL_ad = adata[adata.obs.ident == "ShamL"].copy()

# %%
pst.plot_scatter_image(shamL_ad[shamL_ad.obs.celltype_plot.isin(["Per-SMC"])], 
                  crop=True,
                  xlims = [2550,2750], 
                  ylims = [1300,1450],
                  dpi = 200,
                  color_by="celltype",
                  pt_size=500, 
                  image=True, 
                  ticks=False, 
                  img_alpha = 1,
                  pt_alpha=0.8,
                  cmap = cmap,
                  image_key="ShamL",
                  legend_col=1,
                  save = "Per-SMC.svg")

# %%
pst.plot_scatter_image(shamL_ad,
                  crop=True,
                  xlims = [2550,2750], 
                  ylims = [1300,1450],
                  genes = ["Myh11"], 
                  dpi = 200,
                  pt_size=300, 
                  image=False, 
                  ticks=False, 
                  img_alpha = 1,
                  pt_alpha=0.8,
                  cmap = cmap_red,
                  legend_col=1,
                  save = "Per-SMC_exp.png",
                  format = "png")

# %%
pst.plot_scatter_image(shamL_ad[shamL_ad.obs.celltype_plot.isin(["PC","ICA","ICB"])], 
                  crop=True,
                  ylims = [1200,1350], xlims = [3000,3200],
                  dpi = 200,
                  color_by="celltype",
                  pt_size=500, 
                  image=True, 
                  ticks=False,
                  img_alpha = 1,
                  pt_alpha=0.8,
                  cmap = cmap,
                  image_key="ShamL",
                  legend_col=1,
                  save = "CD.svg")

# %%
pst.plot_scatter_image(shamL_ad,
                  crop=True,
                  ylims = [1200,1350], xlims = [3000,3200],
                  genes = ["Aqp2"], 
                  dpi = 200,
                  color_by="celltype_plot",
                  pt_size=300, 
                  image=False, 
                  ticks=False, 
                  img_alpha = 1,
                  pt_alpha=0.8,
                  cmap = cmap_red,
                  image_key="ShamR",
                  legend_col=1,
                  save = "CD.png",
                  format = "png")

# %%
day2_ad = adata[adata.obs.ident == "Day2L"].copy()

# %%
pst.plot_scatter_image(day2_ad[day2_ad.obs.celltype_plot == "Inj_PT"], 
                  crop=True,
                  xlims=[3400,3600], 
                  ylims=[1630,1780],
                  dpi = 200,
                  color_by="celltype",
                  pt_size=500, 
                  image=True, 
                  ticks=False,
                  img_alpha = 1,
                  pt_alpha=0.8,
                  cmap = cmap,
                  image_key="Day2L",
                  legend_col=1,
                  save = "Inj_PT.svg")

# %%
pst.plot_scatter_image(day2_ad,
                  crop=True,
                  xlims=[3400,3600], 
                  ylims=[1630,1780],
                  genes = ["Havcr1"], 
                  dpi = 200,
                  color_by="celltype",
                  pt_size=300, 
                  image=False, 
                  ticks=False, 
                  img_alpha = 1,
                  pt_alpha=0.8,
                  cmap = cmap_red,
                  image_key="ShamR",
                  legend_col=1,
                  save = "Inj_PT.png",
                  format = "png")

# %%
week6_ad = adata[adata.obs.ident == "Week6R"].copy()

# %%
pst.plot_scatter_image(week6_ad[week6_ad.obs.celltype_plot == "FR_PT"], 
                  crop=True,
                  xlims=[2475,2675],
                  ylims=[4470,4620], 
                  dpi = 200,
                  color_by="celltype",
                  pt_size=500, 
                  image=True, 
                  ticks=False,
                  img_alpha = 1,
                  pt_alpha=0.8,
                  cmap = cmap,
                  image_key="week6R",
                  legend_col=1,
                  save = "FR_PT.svg")

# %%
pst.plot_scatter_image(week6_ad,
                  crop=True,
                  xlims=[2475,2675],
                  ylims=[4470,4620],  
                  genes = ["Vcam1"], 
                  dpi = 200,
                  color_by="celltype",
                  pt_size=300, 
                  image=False, 
                  ticks=False, 
                  img_alpha = 1,
                  pt_alpha=0.8,
                  cmap = cmap_red,
                  legend_col=1,
                  save = "FR_PT.png",
                  format = "png")

# %%
week6L_ad = adata[adata.obs.ident == "Week6L"].copy()

# %%
pst.plot_scatter_image(week6L_ad[week6L_ad.obs.celltype_plot == "Immune"], 
                  crop=True,
                  xlims=[2550,2750],
                  ylims=[2200,2350], 
                  dpi = 200,
                  color_by="celltype",
                  pt_size=500, 
                  image=True, 
                  ticks=False,
                  img_alpha = 1,
                  pt_alpha=0.8,
                  cmap = cmap,
                  image_key="Week6L",
                  legend_col=1,
                  save = "Immune.svg")

# %%
pst.plot_scatter_image(week6L_ad,
                  crop=True,
                  xlims=[2550,2750],
                  ylims=[2200,2350],  
                  genes = ["Cd74"], 
                  dpi = 200,
                  color_by="celltype",
                  pt_size=300, 
                  image=False, 
                  ticks=False, 
                  img_alpha = 1,
                  pt_alpha=0.8,
                  cmap = cmap_red,
                  legend_col=1,
                  save = "Immune_cd74.png",
                  format = "png")
